# %%
! pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.24.2 in c:\users\vadim-pc\anaconda3\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: setuptools in c:\users\vadim-pc\anaconda3\lib\site-packages (from mlxtend) (65.6.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\vadim-pc\anaconda3\lib\site-packages (from mlxtend) (1.2.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\vadim-pc\anaconda3\lib\site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\vadim-pc\anaconda3\lib\site-packages (from mlxtend) (1.10.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\vadim-pc\anaconda3\lib\site-packages (from mlxtend) (3.7.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\vadim-pc\anaconda3\lib\site-packages (from mlxtend) (1.23.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vadim-pc\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vadim-pc\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vadim-pc\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vadim-pc\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vadim-pc\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vadim-pc\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\vadim-pc\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vadim-pc\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (22.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vadim-pc\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vadim-pc\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\vadim-pc\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.22.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from mlxtend.plotting import category_scatter, plot_decision_regions

# %%
data = pd.read_csv('../data/iris.csv', index_col=0)
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data = data.rename(columns={'Species':'y'})
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm               y
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
x_df = data.drop(columns='y')

x_df.head
# Out:
# <bound method NDFrame.head of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id
# 1              5.1           3.5            1.4           0.2
# 2              4.9           3.0            1.4           0.2
# 3              4.7           3.2            1.3           0.2
# 4              4.6           3.1            1.5           0.2
# 5              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 146            6.7           3.0            5.2           2.3
# 147            6.3           2.5            5.0           1.9
# 148            6.5           3.0            5.2           2.0
# 149            6.2           3.4            5.4           2.3
# 150            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]>

# %%
y_df = data[['y']]
y_df.head()
# Out:
#               y
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %%
x_train, x_test, y_train, y_test = train_test_split(x_df, y_df, train_size=0.8, random_state=42)
x_train.shape, x_test.shape
# Out:
# ((120, 4), (30, 4))

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(40,20))  
plot_tree(model, feature_names = x_test.columns, 
             filled=True, fontsize=9, rounded = True)
plt.show()

# %%
train_prediction = model.predict(x_train)
test_prediction = model.predict(x_test)

train_accuracy = accuracy_score(train_prediction, y_train)
test_accuracy = accuracy_score(test_prediction, y_test)

print('Точность на обучающей выборке: ', train_accuracy)
print('Точность на тестовой выборке: ', test_accuracy)
# Out:
# Точность на обучающей выборке:  1.0
# Точность на тестовой выборке:  1.0
